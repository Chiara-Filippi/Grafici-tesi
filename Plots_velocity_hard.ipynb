# %% [markdown]
# ## Simulazioni phabs\*(bapec + bapec) per *Resolve*.

# %% [markdown]
# Sono sotto riportati i grafici, per diversi conteggi, di $T_{fit}/T_{input}$, della metallicità, di $N_{fit}/N_{input}$ e di $v_{fit}/v_{input}$ per la componente calda di uno spettro **phabs*(bapec + bapec)**, fittando un **phabs*(bapec)** con $T_{hot}$ e velocità impostate a 7 keV e a 300 km/s; il range di energie in cui viene effettuato il fit è [2, 10] keV per la prima colonna e [0.5, 10] keV per la seconda.
#
# I grafici sono raggruppati in base al numero di conteggi.
#
# Si nota che, effettuando il fit nel range [2, 10] keV, il discostamento delle quantità fittate rispetto a quelle di input si riduce, dato che il fit sta ignorando la regione fredda dello spettro. Ciò è particolarmente notevole per temperatura e normalizzazione, per le quali inoltre _non_ si ha l'effetto di abbassamento di $T_{fit}$ (e l'innalzamento invece di $N_{fit}$) dovuto alla componente fredda del gas, osservabile invece nel range [0.5, 10] keV e nelle simulazioni precedentemente effettuate.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('Resolve/Velocity/Hard/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;
fig, axes = plt.subplots(4, 4, figsize=(40, 40))

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_resolve = [float(line.split()[6]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_resolve = [float(line.split()[6]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

for k in [0, 1, 2, 3]:
    for l in [0, 1, 2, 3]:
        axes[l, k].set_xlabel('$N_{cold}/N_{hot}$', fontsize = 15)
        axes[l, k].legend()
        axes[l, k].grid(True)
        axes[l, 0].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 1].set_title('$T_{hot} = 10$ keV', fontsize = 15)
        axes[l, 2].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 3].set_title('$T_{hot} = 10$ keV', fontsize = 15)
    axes[0, k].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[1, k].set_ylabel('Metallicità', fontsize = 15)
    axes[2, k].set_ylabel('$N_{fit}/N_{input}$', fontsize = 15)
    axes[3, k].set_ylabel('$V_{fit}/V_{input}$', fontsize = 15)
    axes[0, k].set_ylim([0, 2])
    axes[1, k].set_ylim([0, 0.8])
    axes[2, k].set_ylim([0.5, 1.5])
    axes[3, k].set_ylim([-1, 4])

fig.suptitle('10000 conteggi', fontsize=25, y=0.92)
fig.text(0.315, 0.9, 'Range di energia: [2, 10] keV', ha='center', va='center', fontsize=20)
fig.text(0.715, 0.9, 'Range di energia: [0.5, 10] keV', ha='center', va='center', fontsize=20)

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('Resolve/Velocity/Hard/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;
fig, axes = plt.subplots(4, 4, figsize=(40, 40))

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_resolve = [float(line.split()[6]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_resolve = [float(line.split()[6]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

for k in [0, 1, 2, 3]:
    for l in [0, 1, 2, 3]:
        axes[l, k].set_xlabel('$N_{cold}/N_{hot}$', fontsize = 15)
        axes[l, k].legend()
        axes[l, k].grid(True)
        axes[l, 0].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 1].set_title('$T_{hot} = 10$ keV', fontsize = 15)
        axes[l, 2].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 3].set_title('$T_{hot} = 10$ keV', fontsize = 15)
    axes[0, k].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[1, k].set_ylabel('Metallicità', fontsize = 15)
    axes[2, k].set_ylabel('$N_{fit}/N_{input}$', fontsize = 15)
    axes[3, k].set_ylabel('$V_{fit}/V_{input}$', fontsize = 15)
    axes[0, k].set_ylim([0, 2])
    axes[1, k].set_ylim([0, 0.8])
    axes[2, k].set_ylim([0.5, 1.5])
    axes[3, k].set_ylim([-1, 4])

fig.suptitle('30000 conteggi', fontsize=25, y=0.92)
fig.text(0.315, 0.9, 'Range di energia: [2, 10] keV', ha='center', va='center', fontsize=20)
fig.text(0.715, 0.9, 'Range di energia: [0.5, 10] keV', ha='center', va='center', fontsize=20)

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('Resolve/Velocity/Hard/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;
fig, axes = plt.subplots(4, 4, figsize=(40, 40))

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_resolve = [float(line.split()[6]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[0, i].errorbar(norm[j]-0.015, ratio_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(norm[j]+0.015, ratio_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_resolve = [float(line.split()[6]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[1, i].errorbar(norm[j]-0.015, abun_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1, i].errorbar(norm[j]+0.015, abun_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[2, i].errorbar(norm[j]-0.015, norm_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2, i].errorbar(norm[j]+0.015, norm_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_resolve = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_resolve = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='blueviolet', marker="o", markersize=10)
    
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumorchid', marker="s", markersize=10)
    
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
        else:
            if velocity[j] == 100:
                axes[3, i].errorbar(norm[j]-0.015, velocity_resolve[j], yerr=error_resolve[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3, i].errorbar(norm[j]+0.015, velocity_resolve[j], yerr=error_resolve[j], color='mediumvioletred', marker="D", markersize=10)

for k in [0, 1, 2, 3]:
    for l in [0, 1, 2, 3]:
        axes[l, k].set_xlabel('$N_{cold}/N_{hot}$', fontsize = 15)
        axes[l, k].legend()
        axes[l, k].grid(True)
        axes[l, 0].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 1].set_title('$T_{hot} = 10$ keV', fontsize = 15)
        axes[l, 2].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 3].set_title('$T_{hot} = 10$ keV', fontsize = 15)
    axes[0, k].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[1, k].set_ylabel('Metallicità', fontsize = 15)
    axes[2, k].set_ylabel('$N_{fit}/N_{input}$', fontsize = 15)
    axes[3, k].set_ylabel('$V_{fit}/V_{input}$', fontsize = 15)
    axes[0, k].set_ylim([0, 2])
    axes[1, k].set_ylim([0, 0.8])
    axes[2, k].set_ylim([0.5, 1.5])
    axes[3, k].set_ylim([-1, 4])

fig.suptitle('100000 conteggi', fontsize=25, y=0.92)
fig.text(0.315, 0.9, 'Range di energia: [2, 10] keV', ha='center', va='center', fontsize=20)
fig.text(0.715, 0.9, 'Range di energia: [0.5, 10] keV', ha='center', va='center', fontsize=20)

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('Resolve/Velocity/Hard/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/Hard/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        ratio_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        ratio_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;
fig, axes = plt.subplots(4, 4, figsize=(40, 40))

count = [10000, 30000, 100000]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.05:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_10000 = [float(line.split()[6]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
with open('Resolve/Velocity/Hard/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_30000 = [float(line.split()[6]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

with open('Resolve/Velocity/Hard/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_100000 = [float(line.split()[6]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.05:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/Hard/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]


with open('Resolve/Velocity/Hard/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.05:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.05:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        ratio_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        ratio_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

count = [10000, 30000, 100000]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.05:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_10000 = [float(line.split()[6]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
with open('Resolve/Velocity/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_30000 = [float(line.split()[6]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

with open('Resolve/Velocity/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_100000 = [float(line.split()[6]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.05:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]


with open('Resolve/Velocity/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.05:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.05:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

for k in [0, 1, 2, 3]:
    for l in [0, 1, 2, 3]:
        axes[l, k].set_xlabel('Conteggi', fontsize = 15)
        axes[l, k].legend()
        axes[l, k].grid(True)
        axes[l, k].set_xscale('log')
        axes[l, 0].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 1].set_title('$T_{hot} = 10$ keV', fontsize = 15)
        axes[l, 2].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 3].set_title('$T_{hot} = 10$ keV', fontsize = 15)
    axes[0, k].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[1, k].set_ylabel('Metallicità', fontsize = 15)
    axes[2, k].set_ylabel('$N_{fit}/N_{input}$', fontsize = 15)
    axes[3, k].set_ylabel('$V_{fit}/V_{input}$', fontsize = 15)
    axes[0, k].set_ylim([0.5, 2])
    axes[1, k].set_ylim([0, 1])
    axes[2, k].set_ylim([0.6, 1.1])
    axes[3, k].set_ylim([-1.25, 5.25])
fig.suptitle('$N_{cold}/N_{hot}$ = 0.05', fontsize=25, y=0.92)
fig.text(0.315, 0.9, 'Range di energia: [2, 10] keV', ha='center', va='center', fontsize=20)
fig.text(0.715, 0.9, 'Range di energia: [0.5, 10] keV', ha='center', va='center', fontsize=20)

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('Resolve/Velocity/Hard/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/Hard/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        ratio_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        ratio_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;
fig, axes = plt.subplots(4, 4, figsize=(40, 40))

count = [10000, 30000, 100000]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.1:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_10000 = [float(line.split()[6]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
with open('Resolve/Velocity/Hard/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_30000 = [float(line.split()[6]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

with open('Resolve/Velocity/Hard/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_100000 = [float(line.split()[6]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.1:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/Hard/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]


with open('Resolve/Velocity/Hard/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.1:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.1:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        ratio_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        ratio_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

count = [10000, 30000, 100000]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.1:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_10000 = [float(line.split()[6]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
with open('Resolve/Velocity/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_30000 = [float(line.split()[6]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

with open('Resolve/Velocity/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_100000 = [float(line.split()[6]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.1:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]


with open('Resolve/Velocity/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.1:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.1:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

for k in [0, 1, 2, 3]:
    for l in [0, 1, 2, 3]:
        axes[l, k].set_xlabel('Conteggi', fontsize = 15)
        axes[l, k].legend()
        axes[l, k].grid(True)
        axes[l, k].set_xscale('log')
        axes[l, 0].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 1].set_title('$T_{hot} = 10$ keV', fontsize = 15)
        axes[l, 2].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 3].set_title('$T_{hot} = 10$ keV', fontsize = 15)
    axes[0, k].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[1, k].set_ylabel('Metallicità', fontsize = 15)
    axes[2, k].set_ylabel('$N_{fit}/N_{input}$', fontsize = 15)
    axes[3, k].set_ylabel('$V_{fit}/V_{input}$', fontsize = 15)
    axes[0, k].set_ylim([0.45, 2.8])
    axes[1, k].set_ylim([0, 1])
    axes[2, k].set_ylim([0.6, 1.1])
    axes[3, k].set_ylim([-1.5, 5.25])
fig.suptitle('$N_{cold}/N_{hot}$ = 0.1', fontsize=25, y=0.92)
fig.text(0.315, 0.9, 'Range di energia: [2, 10] keV', ha='center', va='center', fontsize=20)
fig.text(0.715, 0.9, 'Range di energia: [0.5, 10] keV', ha='center', va='center', fontsize=20)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('Resolve/Velocity/Hard/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/Hard/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        ratio_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        ratio_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;
fig, axes = plt.subplots(4, 4, figsize=(40, 40))

count = [10000, 30000, 100000]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.3:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_10000 = [float(line.split()[6]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
with open('Resolve/Velocity/Hard/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_30000 = [float(line.split()[6]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

with open('Resolve/Velocity/Hard/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_100000 = [float(line.split()[6]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.3:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/Hard/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]


with open('Resolve/Velocity/Hard/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.3:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.3:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        ratio_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        ratio_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

count = [10000, 30000, 100000]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.3:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_10000 = [float(line.split()[6]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
with open('Resolve/Velocity/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_30000 = [float(line.split()[6]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

with open('Resolve/Velocity/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_100000 = [float(line.split()[6]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.3:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]


with open('Resolve/Velocity/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.3:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.3:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

for k in [0, 1, 2, 3]:
    for l in [0, 1, 2, 3]:
        axes[l, k].set_xlabel('Conteggi', fontsize = 15)
        axes[l, k].legend()
        axes[l, k].grid(True)
        axes[l, k].set_xscale('log')
        axes[l, 0].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 1].set_title('$T_{hot} = 10$ keV', fontsize = 15)
        axes[l, 2].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 3].set_title('$T_{hot} = 10$ keV', fontsize = 15)
    axes[0, k].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[1, k].set_ylabel('Metallicità', fontsize = 15)
    axes[2, k].set_ylabel('$N_{fit}/N_{input}$', fontsize = 15)
    axes[3, k].set_ylabel('$V_{fit}/V_{input}$', fontsize = 15)
    axes[0, k].set_ylim([0.3, 2.3])
    axes[1, k].set_ylim([0, 1])
    axes[2, k].set_ylim([0.6, 1.5])
    axes[3, k].set_ylim([-2.5, 12])
fig.suptitle('$N_{cold}/N_{hot}$ = 0.3', fontsize=25, y=0.92)
fig.text(0.315, 0.9, 'Range di energia: [2, 10] keV', ha='center', va='center', fontsize=20)
fig.text(0.715, 0.9, 'Range di energia: [0.5, 10] keV', ha='center', va='center', fontsize=20)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('Resolve/Velocity/Hard/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/Hard/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        ratio_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        ratio_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;
fig, axes = plt.subplots(4, 4, figsize=(40, 40))

count = [10000, 30000, 100000]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.5:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_10000 = [float(line.split()[6]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
with open('Resolve/Velocity/Hard/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_30000 = [float(line.split()[6]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

with open('Resolve/Velocity/Hard/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_100000 = [float(line.split()[6]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.5:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/Hard/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]


with open('Resolve/Velocity/Hard/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.5:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/Hard/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/Hard/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 0
    if temp_hot[j] == 10:
        i = 1
    if round(norm[j],2) == 0.5:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/temp_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity = [float(line.split()[0]) for line in lines]
        temp_cold = [float(line.split()[1]) for line in lines]
        temp_hot = [float(line.split()[2]) for line in lines]
        norm = [float(line.split()[3])/float(line.split()[4]) for line in lines]
        ratio_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/temp_resolve_30000.dat') as f:
        lines = f.readlines()
        ratio_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/temp_resolve_100000.dat') as f:
        lines = f.readlines()
        ratio_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

i = 0;

count = [10000, 30000, 100000]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.5:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[0, i].errorbar(count[0]-1000, ratio_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[0, i].errorbar(count[1]-3000, ratio_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[0, i].errorbar(count[2]-10000, ratio_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[0, i].errorbar(count[0]+1000, ratio_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[0, i].errorbar(count[1]+3000, ratio_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[0, i].errorbar(count[2]+10000, ratio_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/abun_resolve_10000.dat') as f:
        lines = f.readlines()
        abun_10000 = [float(line.split()[6]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]
        
with open('Resolve/Velocity/abun_resolve_30000.dat') as f:
        lines = f.readlines()
        abun_30000 = [float(line.split()[6]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

with open('Resolve/Velocity/abun_resolve_100000.dat') as f:
        lines = f.readlines()
        abun_100000 = [float(line.split()[6]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/2 for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.5:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[1,i].errorbar(count[0]-1000, abun_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[1,i].errorbar(count[1]-3000, abun_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[1,i].errorbar(count[2]-10000, abun_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[1,i].errorbar(count[0]+1000, abun_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[1,i].errorbar(count[1]+3000, abun_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[1,i].errorbar(count[2]+10000, abun_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/norm_resolve_10000.dat') as f:
        lines = f.readlines()
        norm_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

with open('Resolve/Velocity/norm_resolve_30000.dat') as f:
        lines = f.readlines()
        norm_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]


with open('Resolve/Velocity/norm_resolve_100000.dat') as f:
        lines = f.readlines()
        norm_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.5:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[2,i].errorbar(count[0]-1000, norm_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[2,i].errorbar(count[1]-3000, norm_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[2,i].errorbar(count[2]-10000, norm_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[2,i].errorbar(count[0]+1000, norm_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[2,i].errorbar(count[1]+3000, norm_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[2,i].errorbar(count[2]+10000, norm_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

with open('Resolve/Velocity/velocity_resolve_10000.dat') as f:
        lines = f.readlines()
        velocity_10000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_10000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/velocity_resolve_30000.dat') as f:
        lines = f.readlines()
        velocity_30000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_30000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]
        
with open('Resolve/Velocity/velocity_resolve_100000.dat') as f:
        lines = f.readlines()
        velocity_100000 = [float(line.split()[6])/float(line.split()[5]) for line in lines]
        error_100000 = [( float(line.split()[8]) - float(line.split()[7]) )/( 2*float(line.split()[5]) ) for line in lines]

for j in range(len(temp_hot)):
    if temp_hot[j] == 5:
        i = 2
    if temp_hot[j] == 10:
        i = 3
    if round(norm[j],2) == 0.5:
        if temp_cold[j] == 0.5:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='darkgreen', marker="P", markersize=10, label="$T_{cold}=0.5$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='darkgreen', marker="P", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='darkgreen', marker="P", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='blueviolet', marker="o", markersize=10, label="$T_{cold}=0.5$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='blueviolet', marker="o", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='blueviolet', marker="o", markersize=10)

        if temp_cold[j] == 1:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='mediumseagreen', marker="X", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='mediumseagreen', marker="X", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='mediumseagreen', marker="X", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumorchid', marker="s", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumorchid', marker="s", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumorchid', marker="s", markersize=10)

        if temp_cold[j] == 2:
            if velocity[j] == 100:
                axes[3,i].errorbar(count[0]-1000, velocity_10000[j], yerr=error_10000[j], color='yellowgreen', marker="H", markersize=10, label="$T_{cold}=1$ keV, $v = 100$ km/s")
                axes[3,i].errorbar(count[1]-3000, velocity_30000[j], yerr=error_30000[j], color='yellowgreen', marker="H", markersize=10)
                axes[3,i].errorbar(count[2]-10000, velocity_100000[j], yerr=error_100000[j], color='yellowgreen', marker="H", markersize=10)
            if velocity[j] == 500:
                axes[3,i].errorbar(count[0]+1000, velocity_10000[j], yerr=error_10000[j], color='mediumvioletred', marker="D", markersize=10, label="$T_{cold}=1$ keV, $v = 500$ km/s")
                axes[3,i].errorbar(count[1]+3000, velocity_30000[j], yerr=error_30000[j], color='mediumvioletred', marker="D", markersize=10)
                axes[3,i].errorbar(count[2]+10000, velocity_100000[j], yerr=error_100000[j], color='mediumvioletred', marker="D", markersize=10)

for k in [0, 1, 2, 3]:
    for l in [0, 1, 2, 3]:
        axes[l, k].set_xlabel('Conteggi', fontsize = 15)
        axes[l, k].legend()
        axes[l, k].grid(True)
        axes[l, k].set_xscale('log')
        axes[l, 0].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 1].set_title('$T_{hot} = 10$ keV', fontsize = 15)
        axes[l, 2].set_title('$T_{hot} = 5$ keV', fontsize = 15)
        axes[l, 3].set_title('$T_{hot} = 10$ keV', fontsize = 15)
    axes[0, k].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[1, k].set_ylabel('Metallicità', fontsize = 15)
    axes[2, k].set_ylabel('$N_{fit}/N_{input}$', fontsize = 15)
    axes[3, k].set_ylabel('$V_{fit}/V_{input}$', fontsize = 15)
    axes[0, k].set_ylim([0.2, 2.1])
    axes[1, k].set_ylim([0, 0.8])
    axes[2, k].set_ylim([0.6, 1.8])
    axes[3, k].set_ylim([-2, 7])
fig.suptitle('$N_{cold}/N_{hot}$ = 0.5', fontsize=25, y=0.92)
fig.text(0.315, 0.9, 'Range di energia: [2, 10] keV', ha='center', va='center', fontsize=20)
fig.text(0.715, 0.9, 'Range di energia: [0.5, 10] keV', ha='center', va='center', fontsize=20)

plt.show()
