# %% [markdown]
# Sono sotto riportati i grafici, in funzione di $N_{cold}/N_{hot}$, di $T_{fit}/T_{input}$ della componente calda, della metallicità e di $N_{cold}/N_{hot}$.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [float(line.split()[2])/float(line.split()[3]) for line in lines]
        ratio = [float(line.split()[5])/float(line.split()[4]) for line in lines]
        error_min = [float(line.split()[5]) - float(line.split()[7]) for line in lines]
        error_max = [ (float(line.split()[5]) - float(line.split()[6]) )/( float(line.split()[4])) for line in lines]
j = 0;
i = 0;
fig, axes = plt.subplots(8, 3, figsize=(30, 80))
t_ref = 3;

for j in range(len(temp_hot)):
    if temp_hot[j] == t_ref:
        if temp_cold[j] == 0.5:
            if round(norm[j],2) == 0.05:
                axes[i, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
            else:
                axes[i, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='cornflowerblue', marker="o", markersize=10)   
        if temp_cold[j] == 1.:
            if round(norm[j],2) == 0.05:
                axes[i, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
            else:
                axes[i, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='mediumvioletred', marker="s", markersize=10)
        if temp_cold[j] == 2.:
            if round(norm[j],2) == 0.05:
                axes[i, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
            else:
                axes[i, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='goldenrod', marker="d", markersize=10)
    if j < len(temp_hot) - 1 and temp_hot[j + 1] != t_ref:
        t_ref += 1
        i += 1

with open('abun.dat') as f:
    lines = f.readlines()
    abun = [float(line.split()[5]) for line in lines]
    error_max = [float(line.split()[5]) - float(line.split()[7]) for line in lines]

i = 0;
t_ref = 3;
for j in range(len(temp_hot)):
    if temp_hot[j] == t_ref:
        if temp_cold[j] == 0.5:
            if round(norm[j],2) == 0.05:
                axes[i, 1].errorbar(norm[j], abun[j], yerr=error_max[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
            else:
                axes[i, 1].errorbar(norm[j], abun[j], yerr=error_max[j], color='cornflowerblue', marker="o", markersize=10)   
        if temp_cold[j] == 1.:
            if round(norm[j],2) == 0.05:
                axes[i, 1].errorbar(norm[j], abun[j], yerr=error_max[j], color='mediumvioletred', marker="s", markersize=10, label="$T_{cold}=1$ keV")
            else:
                axes[i, 1].errorbar(norm[j], abun[j], yerr=error_max[j], color='mediumvioletred', marker="s", markersize=10)
        if temp_cold[j] == 2.:
            if round(norm[j],2) == 0.05:
                axes[i, 1].errorbar(norm[j], abun[j], yerr=error_max[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
            else:
                axes[i, 1].errorbar(norm[j], abun[j], yerr=error_max[j], color='goldenrod', marker="d", markersize=10)
    if j < len(temp_hot) - 1 and temp_hot[j + 1] != t_ref:
        t_ref += 1
        i += 1

with open('norm.dat') as f:
    lines = f.readlines()
    norm_hot = [float(line.split()[4]) for line in lines]
    error_max = [float(line.split()[4]) - float(line.split()[6]) for line in lines]

i = 0;
t_ref = 3;
for j in range(len(temp_hot)):
    if temp_hot[j] == t_ref:
        if temp_cold[j] == 0.5:
            if round(norm[j],2) == 0.05:
                axes[i, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_max[j], marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
            else:
                axes[i, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_max[j], marker="o", markersize=10)   
        if temp_cold[j] == 1.:
            if round(norm[j],2) == 0.05:
                axes[i, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_max[j], marker="s", markersize=10, label="$T_{cold}=1$ keV")
            else:
                axes[i, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_max[j], marker="s", markersize=10)
        if temp_cold[j] == 2.:
            if round(norm[j],2) == 0.05:
                axes[i, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_max[j], marker="d", markersize=10, label="$T_{cold}=2$ keV")
            else:
                axes[i, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_max[j], marker="d", markersize=10)
    if j < len(temp_hot) - 1 and temp_hot[j + 1] != t_ref:
        t_ref += 1
        i += 1

t_ref = 3
for k in [0, 1, 2, 3, 4, 5, 6, 7]:
    for l in [0, 1, 2]:
        axes[k, l].set_title('$T_{hot}$=%i' %t_ref + " keV")
        axes[k, l].set_xlabel('$N_{cold}/N_{hot}$')
        axes[k, l].legend()
        axes[k, l].grid(True)
    axes[k, 0].set_ylabel('$T_{fit}/T_{input}$')
    axes[k, 1].set_ylabel('Metallicità')
    axes[k, 2].set_ylabel('$N_{hot}$')
    axes[k, 0].set_ylim([0.963, 0.992])
    axes[k, 1].set_ylim([0.286, 0.308])
    axes[k, 2].set_ylim([0.65, 0.96])

    t_ref += 1

# %% [markdown]
# Sono sotto riportati i grafici, in funzione di $T_{hot}$, di $T_{fit}/T_{input}$ della componente calda, della metallicità e di $N_{cold}/N_{hot}$.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [round( float(line.split()[2])/float(line.split()[3]), 2 ) for line in lines]
        ratio = [float(line.split()[5])/float(line.split()[4]) for line in lines]
        error_min = [float(line.split()[5]) - float(line.split()[7]) for line in lines]
        error_max = [ (float(line.split()[5]) - float(line.split()[6]) )/( float(line.split()[4])) for line in lines]
j = 0;
i = 0;
fig, axes = plt.subplots(4, 3, figsize=(30, 40))
norm_ref = 0.05;

for j in range(len(temp_hot)):
    if norm[j] == norm_ref:
        if temp_cold[j] == 0.5:
            if temp_hot[j] == 3:
                axes[i, 0].errorbar(temp_hot[j], ratio[j], color='cornflowerblue', yerr=error_max[j], markersize=10, marker="o", label="$T_{cold}=0.5$ keV")
            else:
                axes[i, 0].errorbar(temp_hot[j], ratio[j], color='cornflowerblue', yerr=error_max[j], markersize=10, marker="o")
        if temp_cold[j] == 1.:
            if temp_hot[j] == 3:
                axes[i, 0].errorbar(temp_hot[j], ratio[j], color='mediumvioletred', yerr=error_max[j], markersize=10, marker="s", label="$T_{cold}=1$ keV")
            else:
                axes[i, 0].errorbar(temp_hot[j], ratio[j], color='mediumvioletred', yerr=error_max[j], markersize=10, marker="s")
        if temp_cold[j] == 2.:
            if temp_hot[j] == 3:
                axes[i, 0].errorbar(temp_hot[j], ratio[j], color='goldenrod', yerr=error_max[j], markersize=10, marker="d", label="$T_{cold}=2$ keV")
            else:
                axes[i, 0].errorbar(temp_hot[j], ratio[j], color='goldenrod', yerr=error_max[j], markersize=10, marker="d")

    if j < len(temp_hot) - 1 and norm[j + 1] != norm_ref:
        norm_ref = norm[j+1]
        if norm_ref == 0.05:
            i = 0
            axes[i, 0].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
        elif norm_ref == 0.1:
            i = 1
            axes[i, 0].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
        elif norm_ref == 0.3:
            i = 2
            axes[i, 0].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
        elif norm_ref == 0.5:
            i = 3
            axes[i, 0].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)

norm_ref = 0.05;
i = 0;

with open('abun.dat') as f:
    lines = f.readlines()
    abun = [float(line.split()[5]) for line in lines]
    error_max = [float(line.split()[5]) - float(line.split()[7]) for line in lines]
    
for j in range(len(temp_hot)):
    if norm[j] == norm_ref:
        if temp_cold[j] == 0.5:
            if temp_hot[j] == 3:
                axes[i, 1].errorbar(temp_hot[j], abun[j], color='cornflowerblue', yerr=error_max[j], markersize=10, marker="o", label="$T_{cold}=0.5$ keV")
            else:
                axes[i, 1].errorbar(temp_hot[j], abun[j], color='cornflowerblue', yerr=error_max[j], markersize=10, marker="o")
        if temp_cold[j] == 1.:
            if temp_hot[j] == 3:
                axes[i, 1].errorbar(temp_hot[j], abun[j], color='mediumvioletred', yerr=error_max[j], markersize=10, marker="s", label="$T_{cold}=1$ keV")
            else:
                axes[i, 1].errorbar(temp_hot[j], abun[j], color='mediumvioletred', yerr=error_max[j], markersize=10, marker="s")
        if temp_cold[j] == 2.:
            if temp_hot[j] == 3:
                axes[i, 1].errorbar(temp_hot[j], abun[j], color='goldenrod', yerr=error_max[j], markersize=10, marker="d", label="$T_{cold}=2$ keV")
            else:
                axes[i, 1].errorbar(temp_hot[j], abun[j], color='goldenrod', yerr=error_max[j], markersize=10, marker="d")

    if j < len(temp_hot) - 1 and norm[j + 1] != norm_ref:
        norm_ref = norm[j+1]
        if norm_ref == 0.05:
            i = 0
            axes[i, 0].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
        elif norm_ref == 0.1:
            i = 1
            axes[i, 0].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
        elif norm_ref == 0.3:
            i = 2
            axes[i, 0].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
        elif norm_ref == 0.5:
            i = 3
            axes[i, 0].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)

norm_ref = 0.05;
i = 0;

with open('norm.dat') as f:
    lines = f.readlines()
    norm_hot = [float(line.split()[4]) for line in lines]
    error_max = [float(line.split()[4]) - float(line.split()[6]) for line in lines]
    
for j in range(len(temp_hot)):
    if norm[j] == norm_ref:
        if temp_cold[j] == 0.5:
            if temp_hot[j] == 3:
                axes[i, 2].errorbar(temp_hot[j], norm_hot[j], color='cornflowerblue', yerr=error_max[j], markersize=10, marker="o", label="$T_{cold}=0.5$ keV")
            else:
                axes[i, 2].errorbar(temp_hot[j], norm_hot[j], color='cornflowerblue', yerr=error_max[j], markersize=10, marker="o")
        if temp_cold[j] == 1.:
            if temp_hot[j] == 3:
                axes[i, 2].errorbar(temp_hot[j], norm_hot[j], color='mediumvioletred', yerr=error_max[j], markersize=10, marker="s", label="$T_{cold}=1$ keV")
            else:
                axes[i, 2].errorbar(temp_hot[j], norm_hot[j], color='mediumvioletred', yerr=error_max[j], markersize=10, marker="s")
        if temp_cold[j] == 2.:
            if temp_hot[j] == 3:
                axes[i, 2].errorbar(temp_hot[j], norm_hot[j], color='goldenrod', yerr=error_max[j], markersize=10, marker="d", label="$T_{cold}=2$ keV")
            else:
                axes[i, 2].errorbar(temp_hot[j], norm_hot[j], color='goldenrod', yerr=error_max[j], markersize=10, marker="d")

    if j < len(temp_hot) - 1 and norm[j + 1] != norm_ref:
        norm_ref = norm[j+1]
        for k in [0, 1, 2]:
            if norm_ref == 0.05:
                i = 0
                axes[i, k].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
            elif norm_ref == 0.1:
                i = 1
                axes[i, k].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
            elif norm_ref == 0.3:
                i = 2
                axes[i, k].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)
            elif norm_ref == 0.5:
                i = 3
                axes[i, k].set_title('$N_{cold}/N_{hot}$=%1.2f' %norm_ref)

for k in [0, 1, 2, 3]:
    for l in [0, 1, 2]:
        axes[k, l].set_xlabel('$T_{hot}$')
        axes[k, l].legend()
        axes[k, l].grid(True)
    axes[k, 0].set_ylim([0.962, 0.990])
    axes[k, 1].set_ylim([0.286, 0.306])
    axes[k, 0].set_ylabel('$T_{fit}/T_{input}$')
    axes[k, 1].set_ylabel('Metallicità')
    axes[k, 2].set_ylabel('$N_{hot}$')
