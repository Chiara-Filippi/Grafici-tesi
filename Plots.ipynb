# %% [markdown]
# Sono sotto riportati i grafici, in funzione di $N_{cold}/N_{hot}$, di $T_{fit}/T_{input}$ della componente calda, della metallicità e di $N_{cold}/N_{hot}$.

# %% [markdown]
# ### $T_{hot} = 3 $ keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_3.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4])/float(line.split()[3]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

fig, axes = plt.subplots(3, 1, figsize=(10, 24))

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[0].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[0].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[0].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[0].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='goldenrod')
        j += 1
axes[0].axhline(1.0, color='indigo') # horizontal

axes[0].set_xlabel('$N_{cold}/N_{hot}$')
axes[0].set_ylabel('$T_{fit}/T_{input}$')
axes[0].set_title('Rapporto tra la temperatura ricavata dal fit e quella di input')


with open('abun_3.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[1].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[1].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[1].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[1].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[1].set_xlabel('$N_{cold}/N_{hot}$')
axes[1].set_ylabel('$Metallicità$')
axes[1].set_title('Metallicità del plasma')

with open('norm_3.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[2].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[2].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[2].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[2].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[2].set_xlabel('$N_{cold}/N_{hot}$')
axes[2].set_ylabel('$N_{cold}/N_{hot}$')
axes[2].set_title('Rapporto tra la normalizzazione della componente fredda e quella calda ')

for ax in axes:
    ax.legend()
    ax.grid(True)

# %% [markdown]
# ### $T_{hot} = 4 $ keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_4.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4])/float(line.split()[3]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

fig, axes = plt.subplots(3, 1, figsize=(10, 24))

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[0].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[0].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[0].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[0].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='goldenrod')
        j += 1
axes[0].axhline(1.0, color='indigo') # horizontal

axes[0].set_xlabel('$N_{cold}/N_{hot}$')
axes[0].set_ylabel('$T_{fit}/T_{input}$')
axes[0].set_title('Rapporto tra la temperatura ricavata dal fit e quella di input')


with open('abun_4.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[1].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[1].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[1].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[1].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[1].set_xlabel('$N_{cold}/N_{hot}$')
axes[1].set_ylabel('$Metallicità$')
axes[1].set_title('Metallicità del plasma')

with open('norm_4.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[2].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[2].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[2].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[2].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[2].set_xlabel('$N_{cold}/N_{hot}$')
axes[2].set_ylabel('$N_{cold}/N_{hot}$')
axes[2].set_title('Rapporto tra la normalizzazione della componente fredda e quella calda ')

for ax in axes:
    ax.legend()
    ax.grid(True)

# %% [markdown]
# ### $T_{hot} = 5 $ keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_5.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4])/float(line.split()[3]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

fig, axes = plt.subplots(3, 1, figsize=(10, 24))

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[0].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[0].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[0].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[0].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='goldenrod')
        j += 1
axes[0].axhline(1.0, color='indigo') # horizontal

axes[0].set_xlabel('$N_{cold}/N_{hot}$')
axes[0].set_ylabel('$T_{fit}/T_{input}$')
axes[0].set_title('Rapporto tra la temperatura ricavata dal fit e quella di input')


with open('abun_5.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[1].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[1].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[1].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[1].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[1].set_xlabel('$N_{cold}/N_{hot}$')
axes[1].set_ylabel('$Metallicità$')
axes[1].set_title('Metallicità del plasma')

with open('norm_5.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[2].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[2].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[2].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[2].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[2].set_xlabel('$N_{cold}/N_{hot}$')
axes[2].set_ylabel('$N_{cold}/N_{hot}$')
axes[2].set_title('Rapporto tra la normalizzazione della componente fredda e quella calda ')

for ax in axes:
    ax.legend()
    ax.grid(True)

# %% [markdown]
# ### $T_{hot} = 6 $ keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_6.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4])/float(line.split()[3]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

fig, axes = plt.subplots(3, 1, figsize=(10, 24))

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[0].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[0].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[0].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[0].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='goldenrod')
        j += 1
axes[0].axhline(1.0, color='indigo') # horizontal

axes[0].set_xlabel('$N_{cold}/N_{hot}$')
axes[0].set_ylabel('$T_{fit}/T_{input}$')
axes[0].set_title('Rapporto tra la temperatura ricavata dal fit e quella di input')


with open('abun_6.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[1].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[1].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[1].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[1].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[1].set_xlabel('$N_{cold}/N_{hot}$')
axes[1].set_ylabel('$Metallicità$')
axes[1].set_title('Metallicità del plasma')

with open('norm_6.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[2].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[2].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[2].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[2].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[2].set_xlabel('$N_{cold}/N_{hot}$')
axes[2].set_ylabel('$N_{cold}/N_{hot}$')
axes[2].set_title('Rapporto tra la normalizzazione della componente fredda e quella calda ')

for ax in axes:
    ax.legend()
    ax.grid(True)

# %% [markdown]
# ### $T_{hot} = 7 $ keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_7.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4])/float(line.split()[3]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

fig, axes = plt.subplots(3, 1, figsize=(10, 24))

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[0].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[0].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[0].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[0].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='goldenrod')
        j += 1
axes[0].axhline(1.0, color='indigo') # horizontal

axes[0].set_xlabel('$N_{cold}/N_{hot}$')
axes[0].set_ylabel('$T_{fit}/T_{input}$')
axes[0].set_title('Rapporto tra la temperatura ricavata dal fit e quella di input')


with open('abun_7.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[1].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[1].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[1].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[1].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[1].set_xlabel('$N_{cold}/N_{hot}$')
axes[1].set_ylabel('$Metallicità$')
axes[1].set_title('Metallicità del plasma')

with open('norm_7.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[2].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[2].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[2].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[2].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[2].set_xlabel('$N_{cold}/N_{hot}$')
axes[2].set_ylabel('$N_{cold}/N_{hot}$')
axes[2].set_title('Rapporto tra la normalizzazione della componente fredda e quella calda ')

for ax in axes:
    ax.legend()
    ax.grid(True)

# %% [markdown]
# ### $T_{hot} = 8 $ keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_8.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4])/float(line.split()[3]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

fig, axes = plt.subplots(3, 1, figsize=(10, 24))

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[0].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[0].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[0].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[0].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='goldenrod')
        j += 1
axes[0].axhline(1.0, color='indigo') # horizontal

axes[0].set_xlabel('$N_{cold}/N_{hot}$')
axes[0].set_ylabel('$T_{fit}/T_{input}$')
axes[0].set_title('Rapporto tra la temperatura ricavata dal fit e quella di input')


with open('abun_8.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[1].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[1].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[1].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[1].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[1].set_xlabel('$N_{cold}/N_{hot}$')
axes[1].set_ylabel('$Metallicità$')
axes[1].set_title('Metallicità del plasma')

with open('norm_8.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[2].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[2].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[2].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[2].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[2].set_xlabel('$N_{cold}/N_{hot}$')
axes[2].set_ylabel('$N_{cold}/N_{hot}$')
axes[2].set_title('Rapporto tra la normalizzazione della componente fredda e quella calda ')

for ax in axes:
    ax.legend()
    ax.grid(True)

# %% [markdown]
# ### $T_{hot} = 9 $ keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_9.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4])/float(line.split()[3]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

fig, axes = plt.subplots(3, 1, figsize=(10, 24))

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[0].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[0].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[0].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[0].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='goldenrod')
        j += 1
axes[0].axhline(1.0, color='indigo') # horizontal

axes[0].set_xlabel('$N_{cold}/N_{hot}$')
axes[0].set_ylabel('$T_{fit}/T_{input}$')
axes[0].set_title('Rapporto tra la temperatura ricavata dal fit e quella di input')


with open('abun_9.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[1].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[1].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[1].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[1].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[1].set_xlabel('$N_{cold}/N_{hot}$')
axes[1].set_ylabel('$Metallicità$')
axes[1].set_title('Metallicità del plasma')

with open('norm_9.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[2].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[2].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[2].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[2].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[2].set_xlabel('$N_{cold}/N_{hot}$')
axes[2].set_ylabel('$N_{cold}/N_{hot}$')
axes[2].set_title('Rapporto tra la normalizzazione della componente fredda e quella calda ')

for ax in axes:
    ax.legend()
    ax.grid(True)

# %% [markdown]
# ### $T_{hot} = 10 $ keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_10.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4])/float(line.split()[3]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

fig, axes = plt.subplots(3, 1, figsize=(10, 24))

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[0].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[0].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[0].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[0].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[0].scatter(x[j], y[j], color='goldenrod')
        j += 1
axes[0].axhline(1.0, color='indigo') # horizontal

axes[0].set_xlabel('$N_{cold}/N_{hot}$')
axes[0].set_ylabel('$T_{fit}/T_{input}$')
axes[0].set_title('Rapporto tra la temperatura ricavata dal fit e quella di input')


with open('abun_10.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[1].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[1].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[1].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[1].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[1].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[1].set_xlabel('$N_{cold}/N_{hot}$')
axes[1].set_ylabel('$Metallicità$')
axes[1].set_title('Metallicità del plasma')

with open('norm_10.dat') as f:
        lines = f.readlines()
        x = [float(line.split()[1]) for line in lines]
        y = [float(line.split()[4]) for line in lines]
        z = [float(line.split()[0]) for line in lines]
j = 0;

for z_i in z:
    if z_i==0.500:
        if j == 0:
            axes[2].scatter(x[j], y[j], color='cornflowerblue', label="$T_{cold} = 0.5$ KeV")
        else:
            axes[2].scatter(x[j], y[j], color='cornflowerblue')
        j += 1
    if z_i==1.:
        if j == 4:
            axes[2].scatter(x[j], y[j], color='mediumvioletred', label='$T_{cold} = 1.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='mediumvioletred')
        j += 1
    if z_i==2.:
        if j == 8:
            axes[2].scatter(x[j], y[j], color='goldenrod', label='$T_{cold} = 2.0$ KeV')
        else:
            axes[2].scatter(x[j], y[j], color='goldenrod')
        j += 1

axes[2].set_xlabel('$N_{cold}/N_{hot}$')
axes[2].set_ylabel('$N_{cold}/N_{hot}$')
axes[2].set_title('Rapporto tra la normalizzazione della componente fredda e quella calda ')

for ax in axes:
    ax.legend()
    ax.grid(True)
