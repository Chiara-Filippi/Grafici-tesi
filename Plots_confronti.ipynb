# %% [markdown]
# # Risultati troncando le energie a 0.5 keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_xmm.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [float(line.split()[2])/float(line.split()[3]) for line in lines]
        ratio = [float(line.split()[5])/float(line.split()[4]) for line in lines]
        error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/( 2*float(line.split()[4]) ) for line in lines]
    
j = 0;
i = 0;
fig, axes = plt.subplots(2, 3, figsize=(30, 20))
t_ref = 5;

for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('abun_xmm.dat') as f:
    lines = f.readlines()
    abun = [float(line.split()[5]) for line in lines]
    error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('norm_xmm.dat') as f:
    lines = f.readlines()
    norm_hot = [float(line.split()[4]) for line in lines]
    error_mean = [( float(line.split()[6]) - float(line.split()[5]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10)

with open('temp_resolve.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [float(line.split()[2])/float(line.split()[3]) for line in lines]
        ratio = [float(line.split()[5])/float(line.split()[4]) for line in lines]
        error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/( 2*float(line.split()[4]) ) for line in lines]
    
j = 0;
i = 0;
t_ref = 5;

for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('abun_resolve.dat') as f:
    lines = f.readlines()
    abun = [float(line.split()[5]) for line in lines]
    error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('norm_resolve.dat') as f:
    lines = f.readlines()
    norm_hot = [float(line.split()[4]) for line in lines]
    error_mean = [( float(line.split()[6]) - float(line.split()[5]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10)

t_ref = 5
for k in [0, 1]:
    for l in [0, 1, 2]:
        axes[0, l].set_title('$T_{hot}$=%i' %t_ref + " keV, XMM", fontsize = 15)
        axes[k, l].set_xlabel('$N_{cold}/N_{hot}$', fontsize = 15)
        axes[k, l].legend()
        axes[k, l].grid(True)
    axes[k, 0].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[k, 1].set_ylabel('Metallicità', fontsize = 15)
    axes[k, 2].set_ylabel('$N_{hot}$', fontsize = 15)

for l in [0, 1, 2]:
    axes[0, l].set_title('$T_{hot}$=%i' %t_ref + " keV, XMM", fontsize = 15)
    axes[1, l].set_title('$T_{hot}$=%i' %t_ref + " keV, Resolve", fontsize = 15)

# %% [markdown]
# # Risultati troncando l'energia a 0.3 keV

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_xmm_03.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [float(line.split()[2])/float(line.split()[3]) for line in lines]
        ratio = [float(line.split()[5])/float(line.split()[4]) for line in lines]
        error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/( 2*float(line.split()[4]) ) for line in lines]
    
j = 0;
i = 0;
fig, axes = plt.subplots(2, 3, figsize=(30, 20))
t_ref = 5;

for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('abun_xmm_03.dat') as f:
    lines = f.readlines()
    abun = [float(line.split()[5]) for line in lines]
    error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('norm_xmm_03.dat') as f:
    lines = f.readlines()
    norm_hot = [float(line.split()[4]) for line in lines]
    error_mean = [( float(line.split()[6]) - float(line.split()[5]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10)

with open('temp_resolve_03.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [float(line.split()[2])/float(line.split()[3]) for line in lines]
        ratio = [float(line.split()[5])/float(line.split()[4]) for line in lines]
        error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/( 2*float(line.split()[4]) ) for line in lines]
        error_max = [( float(line.split()[7]) - float(line.split()[5]) )/( float(line.split()[4]) ) for line in lines]
    
j = 0;
i = 0;
t_ref = 5;

for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('abun_resolve_03.dat') as f:
    lines = f.readlines()
    abun = [float(line.split()[5]) for line in lines]
    error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('norm_resolve_03.dat') as f:
    lines = f.readlines()
    norm_hot = [float(line.split()[4]) for line in lines]
    error_mean = [( float(line.split()[6]) - float(line.split()[5]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize = 10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10)

t_ref = 5
for k in [0, 1]:
    for l in [0, 1, 2]:
        axes[k, l].set_xlabel('$N_{cold}/N_{hot}$', fontsize=15)
        axes[k, l].legend()
        axes[k, l].grid(True)
    axes[k, 0].set_ylabel('$T_{fit}/T_{input}$', fontsize=15)
    axes[k, 1].set_ylabel('Metallicità', fontsize=15)
    axes[k, 2].set_ylabel('$N_{hot}$', fontsize=15)

for l in [0, 1, 2]:
    axes[0, l].set_title('$T_{hot}$=%i' %t_ref + " keV, XMM", fontsize=15)
    axes[1, l].set_title('$T_{hot}$=%i' %t_ref + " keV, Resolve", fontsize=15)

#axes[k, 0].set_ylim([0.963, 0.992])
#axes[k, 1].set_ylim([0.286, 0.308])
#axes[k, 2].set_ylim([0.65, 0.96])

# %% [markdown]
# # Confronto tra arf *bet* e *flt*

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_resolve_flt.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [float(line.split()[2])/float(line.split()[3]) for line in lines]
        ratio = [float(line.split()[5])/float(line.split()[4]) for line in lines]
        error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/( 2*float(line.split()[4]) ) for line in lines]
        error_max = [( float(line.split()[7]) - float(line.split()[5]) )/( float(line.split()[4]) ) for line in lines]

j = 0;
i = 0;
fig, axes = plt.subplots(2, 3, figsize=(30, 20))
t_ref = 5;

for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_max[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('abun_resolve_flt.dat') as f:
    lines = f.readlines()
    abun = [float(line.split()[5]) for line in lines]
    error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('norm_resolve_flt.dat') as f:
    lines = f.readlines()
    norm_hot = [float(line.split()[4]) for line in lines]
    error_mean = [( float(line.split()[6]) - float(line.split()[5]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[0, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10)

with open('temp_resolve_03.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [float(line.split()[2])/float(line.split()[3]) for line in lines]
        ratio = [float(line.split()[5])/float(line.split()[4]) for line in lines]
        error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/( 2*float(line.split()[4]) ) for line in lines]
        error_max = [( float(line.split()[7]) - float(line.split()[5]) )/( float(line.split()[4]) ) for line in lines]
    
j = 0;
i = 0;
t_ref = 5;

for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 0].errorbar(norm[j], ratio[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('abun_resolve_03.dat') as f:
    lines = f.readlines()
    abun = [float(line.split()[5]) for line in lines]
    error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='cornflowerblue', marker="o", markersize=10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 1].errorbar(norm[j], abun[j], yerr=error_mean[j], color='goldenrod', marker="d", markersize=10)

with open('norm_resolve_03.dat') as f:
    lines = f.readlines()
    norm_hot = [float(line.split()[4]) for line in lines]
    error_mean = [( float(line.split()[6]) - float(line.split()[5]) )/2 for line in lines]

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='cornflowerblue', yerr=error_mean[j], marker="o", markersize = 10)   
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10, label="$T_{cold}=1$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='mediumvioletred', yerr=error_mean[j], marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            axes[1, 2].errorbar(norm[j], norm_hot[j], color='goldenrod', yerr=error_mean[j], marker="d", markersize=10)

t_ref = 5
for k in [0, 1]:
    for l in [0, 1, 2]:
        axes[k, l].set_xlabel('$N_{cold}/N_{hot}$', fontsize = 15)
        axes[k, l].legend()
        axes[k, l].grid(True)
    axes[k, 0].set_ylabel('$T_{fit}/T_{input}$', fontsize = 15)
    axes[k, 1].set_ylabel('Metallicità', fontsize = 15)
    axes[k, 2].set_ylabel('$N_{hot}$', fontsize = 15)

for l in [0, 1, 2]:
    axes[0, l].set_title('$T_{hot}$=%i' %t_ref + " keV, bet", fontsize = 15)
    axes[1, l].set_title('$T_{hot}$=%i' %t_ref + " keV, flt", fontsize = 15)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

with open('temp_resolve_flt.dat') as f:
        lines = f.readlines()
        temp_cold = [float(line.split()[0]) for line in lines]
        temp_hot = [float(line.split()[1]) for line in lines]
        norm = [float(line.split()[2])/float(line.split()[3]) for line in lines]
        temp_flt = [float(line.split()[5]) for line in lines]
        #error_mean = [( float(line.split()[7]) - float(line.split()[6]) )/( 2*float(line.split()[4]) ) for line in lines]
        error_temp_flt = [( float(line.split()[7]) - float(line.split()[5]) ) for line in lines]

with open('temp_resolve_03.dat') as f:
        lines = f.readlines()
        temp_bet = [float(line.split()[5]) for line in lines]
        error_temp_bet = [( float(line.split()[7]) - float(line.split()[5]) ) for line in lines]

with open('abun_resolve_flt.dat') as f:
        lines = f.readlines()
        abun_flt = [float(line.split()[5]) for line in lines]
        error_abun_flt = [( float(line.split()[7]) - float(line.split()[5]) ) for line in lines]

with open('abun_resolve_03.dat') as f:
        lines = f.readlines()
        abun_bet = [float(line.split()[5]) for line in lines]
        error_abun_bet = [( float(line.split()[7]) - float(line.split()[5]) ) for line in lines]
        
with open('norm_resolve_flt.dat') as f:
        lines = f.readlines()
        norm_flt = [float(line.split()[4]) for line in lines]
        error_norm_flt = [( float(line.split()[6]) - float(line.split()[4]) ) for line in lines]

with open('norm_resolve_03.dat') as f:
        lines = f.readlines()
        norm_bet = [float(line.split()[4]) for line in lines]
        error_norm_bet = [( float(line.split()[6]) - float(line.split()[4]) ) for line in lines]

j = 0;
i = 0;
fig, axes = plt.subplots(3, 1, figsize=(10, 30))
t_ref = 5;

for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            variation = ( temp_bet[j]-temp_flt[j] )/( temp_flt[j] )
            err_1 = ( error_temp_flt[j]*temp_bet[j]/( temp_flt[j]**2 ) )**2
            err_2 = ( error_temp_bet[j]/temp_flt[j] )**2
            axes[0].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            variation = ( temp_bet[j]-temp_flt[j] )/( temp_flt[j] )
            err_1 = ( error_temp_flt[j]*temp_bet[j]/( temp_flt[j]**2 ) )**2
            err_2 = ( error_temp_bet[j]/temp_flt[j] )**2
            axes[0].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='cornflowerblue', marker="o", markersize=10)
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            variation = ( temp_bet[j]-temp_flt[j] )/( temp_flt[j] )
            err_1 = ( error_temp_flt[j]*temp_bet[j]/( temp_flt[j]**2 ) )**2
            err_2 = ( error_temp_bet[j]/temp_flt[j] )**2
            axes[0].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            variation = ( temp_bet[j]-temp_flt[j] )/( temp_flt[j] )
            err_1 = ( error_temp_flt[j]*temp_bet[j]/( temp_flt[j]**2 ) )**2
            err_2 = ( error_temp_bet[j]/temp_flt[j] )**2
            axes[0].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            variation = ( temp_bet[j]-temp_flt[j] )/( temp_flt[j] )
            err_1 = ( error_temp_flt[j]*temp_bet[j]/( temp_flt[j]**2 ) )**2
            err_2 = ( error_temp_bet[j]/temp_flt[j] )**2
            axes[0].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            variation = ( temp_bet[j]-temp_flt[j] )/( temp_flt[j] )
            err_1 = ( error_temp_flt[j]*temp_bet[j]/( temp_flt[j]**2 ) )**2
            err_2 = ( error_temp_bet[j]/temp_flt[j] )**2
            axes[0].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='goldenrod', marker="d", markersize=10)

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            variation = ( abun_bet[j]-abun_flt[j] )/( abun_flt[j] )
            err_1 = ( error_abun_flt[j]*abun_bet[j]/( abun_flt[j]**2 ) )**2
            err_2 = ( error_abun_bet[j]/abun_flt[j] )**2
            axes[1].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            variation = ( abun_bet[j]-abun_flt[j] )/( abun_flt[j] )
            err_1 = ( error_abun_flt[j]*abun_bet[j]/( abun_flt[j]**2 ) )**2
            err_2 = ( error_abun_bet[j]/abun_flt[j] )**2
            axes[1].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='cornflowerblue', marker="o", markersize=10)
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            variation = ( abun_bet[j]-abun_flt[j] )/( abun_flt[j] )
            err_1 = ( error_abun_flt[j]*abun_bet[j]/( abun_flt[j]**2 ) )**2
            err_2 = ( error_abun_bet[j]/abun_flt[j] )**2
            axes[1].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            variation = ( abun_bet[j]-abun_flt[j] )/( abun_flt[j] )
            err_1 = ( error_abun_flt[j]*abun_bet[j]/( abun_flt[j]**2 ) )**2
            err_2 = ( error_abun_bet[j]/abun_flt[j] )**2
            axes[1].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            variation = ( abun_bet[j]-abun_flt[j] )/( abun_flt[j] )
            err_1 = ( error_abun_flt[j]*abun_bet[j]/( abun_flt[j]**2 ) )**2
            err_2 = ( error_abun_bet[j]/abun_flt[j] )**2
            axes[1].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            variation = ( abun_bet[j]-abun_flt[j] )/( abun_flt[j] )
            err_1 = ( error_abun_flt[j]*abun_bet[j]/( abun_flt[j]**2 ) )**2
            err_2 = ( error_abun_bet[j]/abun_flt[j] )**2
            axes[1].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='goldenrod', marker="d", markersize=10)

i = 0;
t_ref = 5;
for j in range(len(temp_hot)):
    if temp_cold[j] == 0.5:
        if round(norm[j],2) == 0.05:
            variation = ( norm_bet[j]-norm_flt[j] )/( norm_flt[j] )
            err_1 = ( error_norm_flt[j]*norm_bet[j]/( norm_flt[j]**2 ) )**2
            err_2 = ( error_norm_bet[j]/norm_flt[j] )**2
            axes[2].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='cornflowerblue', marker="o", markersize=10, label="$T_{cold}=0.5$ keV")
        else:
            variation = ( norm_bet[j]-norm_flt[j] )/( norm_flt[j] )
            err_1 = ( error_norm_flt[j]*norm_bet[j]/( norm_flt[j]**2 ) )**2
            err_2 = ( error_norm_bet[j]/norm_flt[j] )**2
            axes[2].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='cornflowerblue', marker="o", markersize=10)
    if temp_cold[j] == 1.:
        if round(norm[j],2) == 0.05:
            variation = ( norm_bet[j]-norm_flt[j] )/( norm_flt[j] )
            err_1 = ( error_norm_flt[j]*norm_bet[j]/( norm_flt[j]**2 ) )**2
            err_2 = ( error_norm_bet[j]/norm_flt[j] )**2
            axes[2].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='mediumvioletred', marker="s",  markersize=10, label="$T_{cold}=1$ keV")
        else:
            variation = ( norm_bet[j]-norm_flt[j] )/( norm_flt[j] )
            err_1 = ( error_norm_flt[j]*norm_bet[j]/( norm_flt[j]**2 ) )**2
            err_2 = ( error_norm_bet[j]/norm_flt[j] )**2
            axes[2].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='mediumvioletred', marker="s", markersize=10)
    if temp_cold[j] == 2.:
        if round(norm[j],2) == 0.05:
            variation = ( norm_bet[j]-norm_flt[j] )/( norm_flt[j] )
            err_1 = ( error_norm_flt[j]*norm_bet[j]/( norm_flt[j]**2 ) )**2
            err_2 = ( error_norm_bet[j]/norm_flt[j] )**2
            axes[2].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='goldenrod', marker="d", markersize=10, label="$T_{cold}=2$ keV")
        else:
            variation = ( norm_bet[j]-norm_flt[j] )/( norm_flt[j] )
            err_1 = ( error_norm_flt[j]*norm_bet[j]/( norm_flt[j]**2 ) )**2
            err_2 = ( error_norm_bet[j]/norm_flt[j] )**2
            axes[2].errorbar(norm[j], variation, yerr = math.sqrt( err_1 + err_2 ), color='goldenrod', marker="d", markersize=10)

for l in [0, 1, 2]:
    axes[l].set_xlabel('$N_{cold}/N_{hot}$', fontsize=15)
    axes[l].legend()
    axes[l].grid(True)
axes[0].set_ylabel('$(T_{flt}-T_{bet})/T_{flt}$', fontsize=15)
axes[1].set_ylabel('$(A_{flt}-A_{bet})/A_{flt}$', fontsize=15)
axes[2].set_ylabel('$(N_{flt}-N_{bet})/N_{flt}$', fontsize=15)
# Out:
# Text(0, 0.5, '$(N_{flt}-N_{bet})/N_{flt}$')
